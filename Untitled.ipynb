# %%
import pandas as pd
from pandas import DataFrame
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import naive_bayes
from sklearn.metrics import roc_auc_score

# function to create dataframes for text and sentiment
def sentimentDataFrame(filename):
    
    # import train data
    file = open(filename, "r")
    lines = file.readlines()
    lines.pop(0)
    file.close()
    
    # data structure for text and sentiment
    reviews = []
    sentiments = []
    
    # a DataFrame for the text and the corresponding sentiment
    for line in lines: 
        
        index = 0
        char = ''
        
        # find the start of the comment
        while char != ',' and index < len(line):
            
            char = line[index]
            index += 1
        
        
        # score of the the text turned into pos/neg
        score = int(line[-4])
        
        # get the text 
        if score != 3:
            
            review = line[index + 1:-7]
            
            if score >= 4:
                reviews.append(review)
                sentiments.append(1)
            else:
                # append negative reviews more since they are scarce
                # in the data set
                for i in range(7):
                    reviews.append(review)
                    sentiments.append(0)
            
    # creating DataFrame out of text and sentiment
    df = DataFrame({'reviews':reviews, 'sentiments':sentiments})
    return df



# TFIDF Vectorizer - used to convert reviews from text to features
stopset = set(stopwords.words('english'))
vectorizer = TfidfVectorizer(use_idf=True, lowercase=True,
                            strip_accents='ascii', stop_words=stopset)

# dataframes for train and test dataset
train_df = sentimentDataFrame("lab_train.txt")
X_train, y_train = vectorizer.fit_transform(train_df.reviews), train_df.sentiments

test_df = sentimentDataFrame("lab_test.txt")
X_test, y_test = vectorizer.transform(test_df.reviews), test_df.sentiments

# train using naive bayes classifier
clf = naive_bayes.MultinomialNB()
clf.fit(X_train, y_train)

# test models accuracy
print ("Model Accuracy: ", roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))

# import bookings.com comments
comments_df = pd.read_excel("evaluation_dataset.xlsx", header=None, names=['reviews'])
comments_vector = vectorizer.transform(comments_df['reviews'])
comments_df['sentiments'] = clf.predict(comments_vector)

comments_df
# Out:
# Model Accuracy:  0.7172995780590717
#                                                reviews  sentiments
# 0    The check in staff were very friendly and coul...           0
# 1    The room was great - modern & clean. Robes & s...           0
# 2    This is a great hotel. The staff are very frie...           1
# 3    The price of the room which we stayed in was £...           0
# 4    The parking facilities are excellent but did f...           0
# 5    I come to this hotel regularly and I find the ...           0
# 6    Rooms starting to feel their age a little but ...           1
# 7    The place was well located and we were very ha...           0
# 8    Stayed here a few times and it can be a little...           0
# 9    Lovely beds and complimentary water in the roo...           0
# 10   Room is small for a family. has a parking arra...           1
# 11   I was very disappointed that there was no hot ...           0
# 12   Great comfort, cleanliness and loved the swimm...           1
# 13   The beds were so comfy! The hotel staff were r...           1
# 14   Shower not up to current standards. Square in ...           0
# 15   One small gripe- I asked for extra milk in roo...           1
# 16   Really comfy beds, great location for shops. O...           1
# 17   Comfy beds, professional approach from all sta...           1
# 18   The parking situation was pretty nasty. You pa...           1
# 19   Swimming pool was great and decently sized. Bu...           1
# 20   No wi-fi in rooms unless you sign up for marri...           0
# 21   Best hotel breakfast for years. Sensational ha...           1
# 22   i like the hotel location because it's easy to...           0
# 23   I was disappointed with the breakfast. I expec...           0
# 24   Was really nice hotel good location spa was lo...           1
# 25   The WIFI wouldn't work and kept saying I neede...           0
# 26   noisy with open window (airconditioner outlets...           0
# 27   The Bacon at breakfast was decidedly odd. A li...           0
# 28   Carol, the lady who cleared our table at break...           1
# 29   The restaurant leaves a lot to be desired the ...           0
# ..                                                 ...         ...
# 170  Pillows were lumpy and beds were on the small ...           1
# 171  If the general decor and repair of the room wa...           1
# 172  Very impressed with the excellent breakfast. T...           1
# 173  Jacuzzi was really cold. The breakfast was dis...           0
# 174  Breakfast very good and plenty to chose from a...           1
# 175  The bath wasn't as clean as i would have liked...           0
# 176  We loved the size of the room and the comfy be...           1
# 177  Leisure facilities too small for size of hotel...           1
# 178  Nothing I didn't like basic/average room but f...           0
# 179  Paying for parking, other hotels in the area o...           0
# 180  The breakfast was excellent plenty of choice a...           0
# 181  Friendly staff, really helpful. Hotel 5 mins f...           0
# 182  The room was fitted with a desk, obviously for...           0
# 183  Large rooms with all amenities you need Effici...           1
# 184  Staff at the bar at night time were absolutely...           0
# 185  It was my husbands birthday so we got upgraded...           0
# 186  The room was clean and comfy, thought the rest...           0
# 187  Slight walk from centre, staff at breakfast we...           1
# 188  Comfy beds , large room with two double beds ,...           0
# 189  Good solid hotel building ...spacious bedrooms...           1
# 190  Excellent facilities, staff were extremely ple...           0
# 191  The sofa bed was not what I was expecting as I...           0
# 192  Staff were very helpful. Good deal for a Frida...           1
# 193  Problem with the room we booked on booking.com...           0
# 194  The room was extremely hot, making sleeping ve...           0
# 195  The food was great and very affordable! The st...           1
# 196  Had asked for 2 single beds when got there in ...           0
# 197  Room was over warm and air conditioning a litt...           0
# 198  Staff very welcoming and efficient. Excellent ...           0
# 199  The staff were really friend especially the gu...           1
#
# [200 rows x 2 columns]
